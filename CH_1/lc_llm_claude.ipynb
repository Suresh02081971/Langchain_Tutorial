# %%
from langchain.chat_models import init_chat_model

# Initialize Claude model
model = init_chat_model(
    "claude-sonnet-4-5-20250929",  # Current Claude Sonnet 4.5 model
    temperature=0.5,
    timeout=10,
    max_tokens=1000
)

# Use the model
response = model.invoke("Hello, how are you?")
print(response)
# Out:
# c:\Users\sures\Langchain_Tutorial\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# content="Hello! I'm doing well, thank you for asking. How are you doing today? Is there anything I can help you with?" additional_kwargs={} response_metadata={'id': 'msg_017guifcWSKUNwWJQAbd5dvZ', 'model': 'claude-sonnet-4-5-20250929', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 13, 'output_tokens': 30, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-5-20250929', 'model_provider': 'anthropic'} id='lc_run--019bd3e9-6dc7-78d2-bb9f-f744990b3a0b-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 13, 'output_tokens': 30, 'total_tokens': 43, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}}
