# %%
from langchain.chat_models import init_chat_model

# Initialize Claude model
model = init_chat_model(
    "claude-sonnet-4-5-20250929",  # Current Claude Sonnet 4.5 model
    temperature=0.5,
    timeout=10,
    max_tokens=1000
)

# Use the model
response = model.invoke("What is the temperature in chicagotoday?")
print(response)
# Out:
# content='I don\'t have access to real-time information, including current weather conditions or temperatures. To find today\'s temperature in Chicago, I recommend:\n\n1. **Weather websites**: Weather.com, AccuWeather.com, or Weather.gov\n2. **Search engines**: Simply search "Chicago weather" on Google\n3. **Weather apps**: Check apps like Weather Channel, AccuWeather, or your phone\'s built-in weather app\n4. **Voice assistants**: Ask Siri, Google Assistant, or Alexa\n\nThese sources will give you up-to-date temperature and weather conditions for Chicago.' additional_kwargs={} response_metadata={'id': 'msg_01VpbJ3WxGbzAk2KU5v4nMqn', 'model': 'claude-sonnet-4-5-20250929', 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'input_tokens': 17, 'output_tokens': 134, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-5-20250929', 'model_provider': 'anthropic'} id='lc_run--019bd2e1-d9b8-7711-8f4d-a6cd615b33a7-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 17, 'output_tokens': 134, 'total_tokens': 151, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}}
